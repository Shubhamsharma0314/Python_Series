# %% [markdown]
# # Assignment (List + Tuple) -

# %% [markdown]
# ### **Question - 1.** Sort list in ascending and descending order.
# ### **Question - 2.** Find the sum of all the elements in a list.
# ### **Question - 3.** Create a list using List Comprehension.
# ### **Question - 4.** Find unique elements in a list.
# ### **Question - 5.** Find second largest element in the list.
# ### **Question - 6.** Count the evene & odd number in the list
# ### **Question - 7.** Check if a tuple contains duplicate elements.
# ### **Question - 8.** Find the product of all the elements in tuple.
# ### **Questiom - 9.** Create a tuple with one element.
# ### **Question - 10.** Sort a tuple in ascending order.
