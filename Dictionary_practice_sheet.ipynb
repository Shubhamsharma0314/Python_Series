# %% [markdown]
# # Dictionary Practice Sheet -

# %% [markdown]
# **Question-1.**
# Count Frequency of characters in string. s = "programming"  {'p':1, 'r':2, 'o':1, 'g':2, 'a':1, 'm':2, 'i':1, 'n':1}
#
# **Question-2.**
# Create dictionary of cubes (1–10)
#
# **Question-3.**
#  Given a dictionary scores = {"Alice": 85, "Bob": 92, "Charlie": 78}, add a new student "Diana" with a score of 95 and update Bob's score to 88.
#
# **Question-4.**
# Given a list of words, count the frequency of each word using a dictionary.
#
# **Question-5.**
# Given a list of words, count the frequency of each word using a dictionary.
# words = ["apple", "banana", "apple", "cherry", "banana", "apple"]
# Expected: {"apple": 3, "banana": 2, "cherry": 1}
#
# **Question-6.**
# Given a dictionary of student scores, find the student with the highest score.
#
# **Question-7.**
# Group a list of words by their first letter using a dictionary.<br>
# words = ["apple", "ant", "banana", "avocado", "blueberry"]<br>
# Expected: {"a": ["apple", "ant", "avocado"], "b": ["banana", "blueberry"]}
