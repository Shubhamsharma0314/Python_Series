# %% [markdown]
# # Module & Package in Python

# %% [markdown]
# ### Modular Programming -

# %% [markdown]
# Modular programming refers to the process of breaking a large, unwieldy programming task into separate, smaller, more manageable subtasks or modules. Individual modules can then be cobbled together like building blocks to create a larger application.

# %% [markdown]
# There are several advantages to modularizing code in a large application:<br>
# 1. Simplicity
# 2. Maintainability
# 3. Reusability
# 4. Scoping: Modules typically define a separate namespace, which helps avoid collisions between identifiers in different areas of a program.

# %% [markdown]
# ### Types of Modules -
# 1. User defined -> like shubham.py
# 2. Built-in ->  math, random, etc...

# %% [markdown]
# ### import statement

# %% [markdown]
# demo.py file <br>
# code - <br>
# def greet():<br>
# &nbsp;&nbsp;&nbsp;&nbsp;print("Namaste Python!!")

# %% [markdown]
# import demo<br>
# demo.greet()
# - Output <br>
# Namaste Python

# %% [markdown]
# #### Alias(as) -
# import demo as d<br>
# d.greet()
# - Output <br>
# Namaste Python

# %% [markdown]
# ### from module_nmae import statement

# %% [markdown]
# from demo import greet <br>
# greet() <br>
# - Output <br>
# Namaste Python

# %% [markdown]
# ### dir() function -
# The built-in function dir() returns a list of defined names in a namespace. Without arguments, it produces an alphabetically sorted list of names in the current local symbol table

# %% [markdown]
# ### Python Package -
# Packages allow for a hierarchical structuring of the module namespace using dot notation. In the same way that modules help avoid collisions between global variable names, packages help avoid collisions between module names

# %% [markdown]
# package(folder) -> contains files demo.py, demo1,py

# %% [markdown]
# import pack.demo <br>
# pack.demo.greet() <br>
# - Output
# <br>
# Namaste Python!!

# %% [markdown]
# from <package_name> import <modules_name>[, <module_name> ...] <br>
# from <package_name> import <module_name> as <alt_name>

# %% [markdown]
# ### Package Initialization <br>
# __init__.py <br>
# print(f'Invoking __init__.py for {__name__}') <br>
# A = ['quux', 'corge', 'grault'] <br>

# %% [markdown]
# import pkg <br> # Invoking __init__.py for pkg <br>
# pkg.A <br> # ['quux', 'corge', 'grault']

# %% [markdown]
# __init__.py is optional, but still recommended for:
# <br>
# 1. clarity
# 2. compatibility
# 3. initialization logic

# %% [markdown]
# ### import particular file form package -

# %% [markdown]
# from pkg.demo import *

# %% [markdown]
# ### `__all__`

# %% [raw]
# __init__.py file for the package. It imports the necessary modules and defines the __all__ variable to specify which modules should be accessible when importing the package.
#
# __all__ = [
#         'mod1',
#         'mod2',
#         'mod3',
#         'mod4'
#         ]

# %% [markdown]
# Using import * still isn’t considered terrific form, any more for packages than for modules. But this facility at least gives the creator of the package some control over what happens when import * is specified. (In fact, it provides the capability to disallow it entirely, simply by declining to define __all__ at all. As you have seen, the default behavior for packages is to import nothing.)

# %% [raw]
# # mymodule.py
#
# x = 10
# y = 20
# z = 30
#
# __all__ = ["x", "z"]

# %% [raw]
# from mymodule import *
#
# print(x)  # correctly imports x
# print(z)  # correctly imports z
# print(y)  # ❌ # This will raise a NameError because 'y' is not included in __all__

# %% [raw]
# Even if something is not in __all__, you can still access it:
# import mymodule
# print(mymodule.y)  #  This will work because 'y' is still accessible as an attribute of the mymodule module, even though it is not included in __all__.

# %% [markdown]
#  `__all__ `is used by both packages and modules to control what is imported when import * is specified. But the default behavior differs:
# <br>
# For a package, when `__all__ `is not defined, import * does not import anything.<br>
# For a module, when `__all__` is not defined, import * imports everything (except—you guessed it—names starting with an underscore).

# %% [markdown]
# #### Subpackages - Packages can contain nested subpackages to arbitrary depth.

# %% [markdown]
# pck(package)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;subpck<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;mod1<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;mod2<br>
# &nbsp;&nbsp;&nbsp;&nbsp;subpck1<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;mod3<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;mod4<br>

# %% [markdown]
# ### Absolute and Relative Imports in Python -

# %% [markdown]
# project <br>
# &nbsp;&nbsp;&nbsp;&nbsp;pkg1 <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;module1.py<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;module2.py<br>
# &nbsp;&nbsp;&nbsp;&nbsp;pkg2<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;module3.py<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;module4.py<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;subpkg1.py<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;module4.py<br>

# %% [markdown]
# - pkg1 / module1.py contain a function, fun1
# - pkg2 / module3.py contain a function, fun2
# - pkg2 / subpkg1 / module5.py contain a function fun3

# %% [raw]
# # absolute imports - we are importing the modules by writing the full path from its root folder
#
# # importing a fun1 from pkg1/module1
# from pkg1.import module1 import fun1
#
# from pkg1 import module2
#
# # importing a fun2 from pkg2/module3
# from pkg2 import module3 import fun2
#
# # importing a fun3 from pkg2/subpkg1/module5
# from pkg2.subpkg1.module5 import fun3

# %% [markdown]
# Relative import specifies an object or module imported from its current location, that is the location where import statement resides.

# %% [raw]
# # relative imports
#
# # importing fun1 into pkg1/module1.py
# from .module1 import fun1
#
# # importing fun2 and fun3 into pkg2/module3.py
# from .module3 import fun2
# from .subpackage1.module5 import fun3

# %% [markdown]
# #### Import from same package

# %% [raw]
# # module1.py
# from . import module2   # same level (if exists)

# %% [markdown]
# #### Import from parent package

# %% [raw]
# # module2.py
# from .. import module1  # one level up (if exists)

# %% [markdown]
# #### Import specific object

# %% [raw]
# from .module1 import some_function

# %% [markdown]
# #### Meaning of Dots <br>
# a . → current package <br>
# b .. → one level up <br>
# c ... → two levels up <br>
