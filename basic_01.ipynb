# %% [markdown]
# # Python Introduction

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print(12)
# Out:
# 12

# %%
print("Shubham sharma")
# Out:
# Shubham sharma

# %%
print("Shubham")
print("sharma")
# Out:
# Shubham
# sharma

# %%
print("shubham", "\n", "sharma")
# Out:
# shubham
#  sharma

# %% [markdown]
# # Comment-
# 1. Single Line comment -> #
# 2. Multiple line comment -> ''' '''

# %%
# This is for greeting the user
print("Hello, Shubham!")
# Out:
# Hello, Shubham!

# %%
'''
This is a multi-line comment
that spans several lines.
It is often used for documentation.
'''
print("Multi-line comment example")
# Out:
# Multi-line comment example

# %% [markdown]
# # Variables
# - syntax :
# variable_name = variable_value

# %%
a="shubham"
print(a)
# Out:
# shubham

# %% [markdown]
# Rules For Variable Names -
# 1. Can't Start with number.
# 2. Can't contains any special character except underscore(_).
# 3. Case-Sensitive(a & A are different variable).
# 4. Can't use reserved Keywords.(if,for,etc....)

# %%
print("Students management system")
student_name = "Shubham Sharma"
student_age = 21
student_course = "Computer Science"
print("Name:", student_name)
print("Age:", student_age)
print("Course:", student_course)
# Out:
# Students management system
# Name: Shubham Sharma
# Age: 21
# Course: Computer Science

# %% [markdown]
# # Input From User -

# %%
#input() : -
a=input("Enter your name: ")
print("Your name is:",a)
# Out:
# Your name is: shubham

# %%
#type() : -
x= 10
print("The type of x is:", type(x))
y= "Shubham"
print("The type of y is:", type(y))
z= 5.67
print("The type of z is:", type(z))
# Out:
# The type of x is: <class 'int'>
# The type of y is: <class 'str'>
# The type of z is: <class 'float'>

# %%
n=input("Enter a number: ")
print(type(n))
# Out:
# <class 'str'>

# %% [markdown]
# # Type Casting -
# - Conversion of One data type into another data type
# 1. int() -> for interger
# 2. float() -> for floating number
# 3. str() -> for string
# - Note : Bydefault input() function have data type string.

# %% [markdown]
# - Addition of two numbers -

# %%
num1=int(input("Enter first number: "))
num2=int(input("Enter second number: "))
sum =num1 + num2
print("The sum is:",sum)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 num1=int(input("Enter first number: "))
#       2 num2=int(input("Enter second number: "))
#       3 sum =num1 + num2
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
num1=float(input("Enter first number: "))
num2=float(input("Enter second number: "))
sum =num1 + num2
print("The sum is:",sum)
# Out:
# The sum is: 20.5

# %%
print("Employee Management System")
employee_name = input("Enter employee name: ")
employee_id = input("Enter employee ID: ")
employee_department = input("Enter employee department: ")
employee_salary = float(input("Enter employee salary: "))
print("\nEmployee Details:")
print("Name:", employee_name)
print("ID:", employee_id)
print("Department:", employee_department)
print("Salary:", employee_salary)
# Out:
# Employee Management System
#
# Employee Details:
# Name: shubham
# ID: 1001
# Department: Software
# Salary: 123456.0
