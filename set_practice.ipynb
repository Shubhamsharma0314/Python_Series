# %% [markdown]
# # Set Practice Sheet
#
# **Question-1.**
# Given a list [1, 2, 2, 3, 4, 4, 5], use a set to remove duplicates and return a sorted list.
#
# **Question-2.**
# Write a program unique_chars(s1, s2) that returns characters present in s1 but not in s2.
#
# **Question-3.**
# Write a program that takes two lists and returns True if they share no common elements.
#
# **Question-4.**
# Given a sentence, find all unique words (case-insensitive) and print them in alphabetical order.
#
# **Question-5.**
# Given a list of strings, find characters that appear in every single string.words = ["hello", "world", "hold"]  # → {'h', 'o', 'l'}
